# %%
import pandas as pd

# %%
student_data_to_load = "Resources/students_complete.csv"

# %%
student_data_df = pd.read_csv(student_data_to_load)
student_data_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Dr. Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Dr. Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
name = "Mrs. Linda Santiago"
print(name)
name.split()
# Out:
# Mrs. Linda Santiago
# ['Mrs.', 'Linda', 'Santiago']

# %%
for sname in student_names:
    if len(sname.split()) > 2:
        print(sname.split(), len(sname.split()))
# Out:
# ['Dr.', 'Richard', 'Scott'] 3
# ['Dr.', 'Jordan', 'Carson'] 3
# ['Madeline', 'Snyder', 'MD'] 3
# ['Mr.', 'Dylan', 'Taylor', 'MD'] 4
# ['Dr.', 'Scott', 'Gill'] 3
# ['Miss', 'Madison', 'Everett'] 3
# ['Virginia', 'Ramirez', 'MD'] 3
# ['Joseph', 'Morales', 'III'] 3
# ['Angela', 'Perkins', 'DVM'] 3
# ['Heather', 'Allen', 'MD'] 3
# ['Luke', 'Lowery', 'MD'] 3
# ['Dr.', 'Larry', 'Hines'] 3
# ['Emily', 'Cardenas', 'MD'] 3
# ['Mrs.', 'Elizabeth', 'Espinoza', 'DDS'] 4
# ['Mrs.', 'Lisa', 'Becker'] 3
# ['Mr.', 'Travis', 'Young'] 3
# ['Paula', 'Fernandez', 'DVM'] 3
# ['Dr.', 'Xavier', 'Bell', 'II'] 4
# ['Andrew', 'Hanson', 'MD'] 3
# ['Mr.', 'Roberto', 'Wright', 'MD'] 4
# ['Mr.', 'Dale', 'Miller'] 3
# ['Mary', 'Gonzalez', 'DDS'] 3
# ['Mrs.', 'Cindy', 'Brown'] 3
# ['James', 'White', 'MD'] 3
# ['Donald', 'Gill', 'DDS'] 3
# ['Mrs.', 'Catherine', 'Williams', 'MD'] 4
# ['Ashley', 'Caldwell', 'MD'] 3
# ['Mr.', 'Jared', 'Campbell'] 3
# ['Michael', 'Moreno', 'PhD'] 3
# ['Tara', 'Parker', 'MD'] 3
# ...

# %%
# Create new list of names to fix
snames_to_fix = []

# examine all names with 3 or more words
for sname in student_names:
    if len(sname.split()) >= 3: 
        snames_to_fix.append(sname)

# Get the number of students with names >= 3
len(snames_to_fix)
# Out:
# 1531

# %%
prefixes = []
for sname in snames_to_fix:
    if len(sname.split()[0]) <= 4:
        prefixes.append(sname.split()[0])
        
print(prefixes)
# Out:
# ['Dr.', 'Dr.', 'Mr.', 'Dr.', 'Miss', 'Luke', 'Dr.', 'Mrs.', 'Mrs.', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mary', 'Mrs.', 'Mrs.', 'Mr.', 'Tara', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'John', 'Mr.', 'Mrs.', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Dale', 'Dr.', 'Dr.', 'Dr.', 'Ms.', 'Dr.', 'Dr.', 'Mr.', 'Mrs.', 'Amy', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mrs.', 'Mrs.', 'Mr.', 'Lisa', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Mr.', 'Mark', 'Mrs.', 'Dr.', 'Dr.', 'Miss', 'Mr.', 'Miss', 'Mr.', 'Mrs.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Dr.', 'Miss', 'Mr.', 'Mrs.', 'Mr.', 'Tara', 'Dr.', 'Mr.', 'Cody', 'Mr.', 'Dr.', 'Mr.', 'Ms.', 'Dr.', 'Mr.', 'Mrs.', 'Sara', 'Mr.', 'Mrs.', 'Dr.', 'Mr.', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Mrs.', 'Mr.', 'Mrs.', 'Dr.', 'Ryan', 'Mrs.', 'Mr.', 'Ms.', 'Mr.', 'Dr.', 'John', 'Mr.', 'Dr.', 'Dr.', 'Mrs.', 'Dr.', 'Mrs.', 'Mr.', 'Mr.', 'Mrs.', 'Dr.', 'Dr.', 'Miss', 'Miss', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Dr.', 'Mrs.', 'Mr.', 'Ms.', 'Mr.', 'Miss', 'Tony', 'Dr.', 'M
# ...

# %%
suffixes = []

for sname in snames_to_fix:
    if len(sname.split()[-1]) <=3:
        suffixes.append(sname.split()[-1])
        
print(suffixes)
# Out:
# ['MD', 'MD', 'MD', 'III', 'DVM', 'MD', 'MD', 'MD', 'DDS', 'DVM', 'II', 'MD', 'MD', 'DDS', 'MD', 'DDS', 'MD', 'MD', 'PhD', 'MD', 'DVM', 'Lee', 'MD', 'DDS', 'MD', 'MD', 'MD', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'DVM', 'MD', 'MD', 'PhD', 'IV', 'MD', 'DDS', 'DDS', 'DDS', 'MD', 'DDS', 'MD', 'DVM', 'IV', 'MD', 'DDS', 'MD', 'MD', 'DVM', 'Jr.', 'MD', 'PhD', 'II', 'MD', 'DDS', 'DDS', 'DDS', 'Jr.', 'III', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'DDS', 'DVM', 'DDS', 'DVM', 'MD', 'DDS', 'PhD', 'DDS', 'DDS', 'Jr.', 'Jr.', 'DVM', 'DDS', 'MD', 'MD', 'DVM', 'DDS', 'DVM', 'Jr.', 'MD', 'Jr.', 'MD', 'PhD', 'PhD', 'DDS', 'MD', 'DDS', 'DVM', 'Cox', 'DVM', 'MD', 'Jr.', 'MD', 'DDS', 'MD', 'MD', 'DDS', 'DDS', 'Roy', 'DDS', 'DDS', 'DDS', 'II', 'PhD', 'MD', 'PhD', 'DDS', 'MD', 'DDS', 'Jr.', 'Day', 'DDS', 'MD', 'PhD', 'DDS', 'Jr.', 'DDS', 'MD', 'MD', 'MD', 'MD', 'DDS', 'MD', 'DDS', 'PhD', 'DVM', 'DDS', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'Jr.', 'DDS', 'Jr.', 'MD', 'MD', 'PhD', 'PhD', 'DDS', 'MD', 'MD', 'III', 'DVM', 'PhD', 'J
# ...

# %%
set(prefixes)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
# this does not work, but I was trying to isolate prefs ending in .
for pref in prefixes:
    if pref.split()[-1] = ".":
        print(pref)
# Out:
#   File "C:\Users\kmbur\AppData\Local\Temp/ipykernel_17692/541839955.py", line 2
#     if pref.split()[-1] = ".":
#                         ^
# SyntaxError: invalid syntax

# %%
for sname in snames_to_fix:
    print(sname.strip("Mrs."))
# Out:
# Dr. Richard Scott
# Dr. Jordan Carson
# adeline Snyder MD
#  Dylan Taylor MD
# Dr. Scott Gill
# iss Madison Everett
# Virginia Ramirez MD
# Joseph Morales III
# Angela Perkins DV
# Heather Allen MD
# Luke Lowery MD
# Dr. Larry Hine
# Emily Cardenas MD
#  Elizabeth Espinoza DDS
#  Lisa Becke
#  Travis Young
# Paula Fernandez DV
# Dr. Xavier Bell II
# Andrew Hanson MD
#  Roberto Wright MD
#  Dale Mille
# ary Gonzalez DDS
#  Cindy Brown
# James White MD
# Donald Gill DDS
#  Catherine Williams MD
# Ashley Caldwell MD
#  Jared Campbell
# ichael Moreno PhD
# Tara Parker MD
# Shawn Williams DV
# Dr. Alicia Martinez
#  Timothy Anderson
#  Paula Lee
#  Elijah Hall
#  Raymond Stone
# John Dickerson MD
#  Alex Franklin
#  Jessica Dunn
#  Michael Stevenson
# Jason Jones DDS
# Adriana Wade MD
# Erica Hurley MD
# Dr. Garrett Wright
#  James Allen
#  Timothy Harper MD
# Dale Brown MD
# Dr. Christina Moore
# Angela Peterson MD
# Jennifer Ferguson MD
# Anthony Wilson DDS
# Dr. Jessica Lopez
# ...

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# %%
for fix in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(fix, "")
# Out:
# C:\Users\kmbur\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
print(student_data_df.head(10))
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School             66
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 3           3    Richard Scott      M  12th  Huang High School             67
# 4           4       Bonnie Ray      F   9th  Huang High School             97
# 5           5    Bryan Miranda      M   9th  Huang High School             94
# 6           6    Sheena Carter      F  11th  Huang High School             82
# 7           7     Nicole Baker      F  12th  Huang High School             96
# 8           8     Michael Roth      M  10th  Huang High School             95
# 9           9   Matthew Greene      M  10th  Huang High School             96
#
#    math_score
# 0          79
# 1          61
# 2          60
# 3          58
# 4          84
# 5          94
# ...

# %%
# Put the cleaned students' names in another list.
student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
students_fixed = []

for name in student_names:
    if len(name.split()) >= 3:
        students_fixed.append(name)
        
len(students_fixed)
# Out:
# 151

# %%
print(students_fixed)
# Out:
# ['Joseph Morales III', 'Xavier Bell II', 'David Miller Jr.', 'Reginald Garcia IV', 'Kevin Brown IV', 'William Washington Jr.', 'Juan Bryant II', 'Kenneth Paul Jr.', 'Scott Rivers III', 'Mark Myers Jr.', 'Michael Norton Jr.', 'Sean Pena Jr.', 'Cody Mueller Jr.', 'Mathew White Jr.', 'Jason Daugherty Jr.', 'Leonard Webster II', 'Michael Stein Jr.', 'Ryan Phillips Jr.', 'Allen Snyder Jr.', 'Calvin Williams Jr.', 'Ronald Torres Jr.', 'Gabriel Smith III', 'Brian Pitts Jr.', 'Bruce Thompson II', 'Jeremy Sanders II', 'Austin Johnson II', 'Bryan Conway Jr.', 'Ronald Moore II', 'Robert Garrison IV', 'William Gonzalez Jr.', 'Brian Matthews Jr.', 'Eric Richards Jr.', 'Kenneth Munoz Jr.', 'Jon Delgado Jr.', 'Andrew English Jr.', 'Raymond Cox Jr.', 'Jeffrey Mcclain Jr.', 'Brian Poole V', 'Jeffrey Kim II', 'Matthew Alexander Jr.', 'Kevin Reynolds Jr.', 'Jacob Skinner Jr.', 'Dennis Gibson Jr.', 'Jimmy Shea Jr.', 'James Reed Jr.', 'Jeffery Baker Jr.', 'Derrick Hughes III', 'Joshua Rivera Jr.', 'Timot
# ...
